# %%
# Import necessary libraries
import torch
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor, Normalize, Compose
from datasets import load_dataset
import numpy as np
from flwr_datasets import FederatedDataset
from flwr_datasets.partitioner import IidPartitioner, DirichletPartitioner
from flwr.client import NumPyClient
from flwr.common import Context, NDArrays, Scalar, ndarrays_to_parameters, EvaluateRes
from flwr.server import ServerApp, ServerConfig, ServerAppComponents
from flwr.server.strategy import FedProx  # Changed from FedAvg to FedProx
from flwr.simulation import run_simulation
from collections import OrderedDict
from typing import Dict, Tuple, List
import torch.nn as nn
import torch.nn.functional as F
from sklearn.metrics import cohen_kappa_score, f1_score, roc_auc_score
from sklearn.preprocessing import label_binarize
from flwr.server.client_proxy import ClientProxy
from flwr.common.logger import log
from logging import INFO

from flwr.server.strategy import DifferentialPrivacyClientSideFixedClipping

# Additional imports for plotting and data saving
import matplotlib.pyplot as plt
import pandas as pd
import random
import os

# Set random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed()

# Define constants
NUM_CLIENTS = 5
NUM_ROUNDS = 50
BATCH_SIZE = 32

NOISE_MULTIPLIER = 1.0  # Increased to 1.0 for stronger privacy
CLIPPING_NORM = 20.0     # Threshold for clipping model updates

# Function to run simulation for a given scenario
def run_simulation_scenario(ATTACKER_IDS, USE_IID):
    # Define partitioner based on IID or non-IID
    if USE_IID:
        # IID Partitioning
        partitioner = IidPartitioner(num_partitions=NUM_CLIENTS)
    else:
        # Non-IID Partitioning using Dirichlet distribution
        alpha = 1.0  # Adjust alpha for desired heterogeneity
        partitioner = DirichletPartitioner(num_partitions=NUM_CLIENTS, alpha=alpha, partition_by="label")

    # Load the CIFAR-10 dataset and partition it
    fds = FederatedDataset(dataset="cifar10", partitioners={"train": partitioner})

    def get_cifar10_dataloaders(cifar10_dataset, batch_size: int):
        """
        Function to handle CIFAR-10 data loaders.
        Applies appropriate transformations for CIFAR-10 images.
        """
        # CIFAR-10 normalization parameters
        pytorch_transforms = Compose([
            ToTensor(),
            Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
        ])

        # Prepare transformation functions
        def apply_transforms(batch):
            """Apply transforms to the partition from FederatedDataset."""
            batch["img"] = [pytorch_transforms(img) for img in batch["img"]]
            return batch

        cifar10_dataset = cifar10_dataset.with_transform(apply_transforms)

        # Construct PyTorch dataloader
        dataloader = DataLoader(cifar10_dataset, batch_size=batch_size, shuffle=True)
        return dataloader

    # Define the neural network model suitable for CIFAR-10
    class Net(nn.Module):
        def __init__(self, num_classes: int) -> None:
            super(Net, self).__init__()
            self.conv1 = nn.Conv2d(3, 6, 5)  # Changed input channels from 1 to 3 for CIFAR-10
            self.pool = nn.MaxPool2d(2, 2)
            self.conv2 = nn.Conv2d(6, 16, 5)
            self.fc1 = nn.Linear(16 * 5 * 5, 120)  # Adjusted for 32x32 images
            self.fc2 = nn.Linear(120, 84)
            self.fc3 = nn.Linear(84, num_classes)

        def forward(self, x: torch.Tensor) -> torch.Tensor:
            x = self.pool(F.relu(self.conv1(x)))
            x = self.pool(F.relu(self.conv2(x)))
            x = x.view(-1, 16 * 5 * 5)
            x = F.relu(self.fc1(x))
            x = F.relu(self.fc2(x))
            x = self.fc3(x)
            return x

    # Functions to set and get model parameters
    def set_params(model, parameters):
        """Replace model parameters with those passed as parameters."""
        params_dict = zip(model.state_dict().keys(), parameters)
        state_dict = OrderedDict({k: torch.from_numpy(v) for k, v in params_dict})
        model.load_state_dict(state_dict, strict=True)

    def get_params(model):
        """Extract model parameters as a list of NumPy arrays."""
        return [val.cpu().numpy() for _, val in model.state_dict().items()]

    # Training function with label flipping for attackers and proximal term
    def train(net, trainloader, optimizer, device="cpu", is_attacker=False, global_params=None, mu=0.1):
        """Train the network on the training set with optional proximal term."""
        criterion = torch.nn.CrossEntropyLoss()
        net.to(device)
        net.train()
        for batch in trainloader:
            images, labels = batch["img"].to(device), batch["label"].to(device)
            optimizer.zero_grad()
            if is_attacker:
                # Flip labels for attackers (simple label flipping)
                labels = (labels + 1) % 10
            outputs = net(images)
            loss = criterion(outputs, labels)
            if global_params is not None:
                # Add proximal term
                proximal_loss = 0.0
                for param, global_param in zip(net.parameters(), global_params.values()):
                    proximal_loss += torch.norm(param - global_param.to(device))**2
                loss += (mu / 2) * proximal_loss
            loss.backward()
            optimizer.step()

    # Testing function with metric calculations
    def test(net, testloader, device):
        """Validate the network on the entire test set."""
        criterion = torch.nn.CrossEntropyLoss()
        net.to(device)
        net.eval()
        correct, loss = 0, 0.0
        all_preds = []
        all_labels = []
        all_outputs = []
        with torch.no_grad():
            for batch in testloader:
                images, labels = batch["img"].to(device), batch["label"].to(device)
                outputs = net(images)
                loss += criterion(outputs, labels).item()
                _, predicted = torch.max(outputs.data, 1)
                correct += (predicted == labels).sum().item()
                all_preds.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
                all_outputs.extend(outputs.cpu().numpy())
        accuracy = correct / len(testloader.dataset)

        # Compute metrics
        kappa = cohen_kappa_score(all_labels, all_preds)
        f1 = f1_score(all_labels, all_preds, average='macro')

        # Check if there are at least two classes in y_true
        unique_classes = np.unique(all_labels)
        if len(unique_classes) > 1:
            try:
                all_labels_bin = label_binarize(all_labels, classes=list(range(10)))
                all_outputs_array = np.array(all_outputs)
                roc_auc = roc_auc_score(all_labels_bin, all_outputs_array, average='macro', multi_class='ovr')
            except ValueError:
                roc_auc = float('nan')  # Assign NaN if ROC AUC cannot be computed
        else:
            roc_auc = float('nan')  # Assign NaN if only one class is present

        metrics = {
            "accuracy": accuracy,
            "kappa": kappa,
            "f1_score": f1,
            "roc_auc": roc_auc,
        }
        return loss, accuracy, metrics

    # Initialize metrics lists
    rounds_list = []
    accuracy_list = []
    kappa_list = []
    f1_list = []
    roc_auc_list = []

    # Define the FlowerClient class
    class FlowerClient(NumPyClient):
        def __init__(self, trainloader, valloader, is_attacker=False) -> None:
            super().__init__()
            self.trainloader = trainloader
            self.valloader = valloader
            self.model = Net(num_classes=10)
            self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
            self.is_attacker = is_attacker

        def fit(self, parameters, config):
            """Train the model locally with FedProx proximal term."""
            # Set model parameters
            set_params(self.model, parameters)

            # Extract global parameters from config
            global_params = OrderedDict(
                (k, torch.tensor(v)) for k, v in zip(self.model.state_dict().keys(), parameters)
            )

            # Get proximal_mu from config
            mu = config.get("proximal_mu", 0.1)  # Default to 0.1 if not set

            # Define the optimizer
            optim = torch.optim.SGD(self.model.parameters(), lr=0.01, momentum=0.9)

            # Train the model with proximal term
            train(
                self.model,
                self.trainloader,
                optim,
                self.device,
                is_attacker=self.is_attacker,
                global_params=global_params,
                mu=mu  # Proximal term coefficient
            )

            # **Apply Client-Side Fixed Clipping**
            updated_params = get_params(self.model)
            clipped_params = []
            for param in updated_params:
                norm = np.linalg.norm(param)
                if norm > CLIPPING_NORM:
                    param = param * (CLIPPING_NORM / norm)
                clipped_params.append(param)

            # Return clipped parameters
            return clipped_params, len(self.trainloader.dataset), {}

        def evaluate(self, parameters: NDArrays, config: Dict[str, Scalar]):
            """Evaluate the model locally."""
            set_params(self.model, parameters)
            loss, accuracy, metrics = test(self.model, self.valloader, self.device)
            return float(loss), len(self.valloader.dataset), metrics

    # Define the client function
    def client_fn(context: Context):
        """Create a Flower client representing a participant in the federated learning."""
        partition_id = int(context.node_config["partition-id"])
        partition = fds.load_partition(partition_id, "train")
        # Partition into train/validation
        partition_train_val = partition.train_test_split(test_size=0.1, seed=42)
        # Get dataloaders
        trainloader = get_cifar10_dataloaders(partition_train_val["train"], batch_size=BATCH_SIZE)
        valloader = get_cifar10_dataloaders(partition_train_val["test"], batch_size=BATCH_SIZE)
        # Determine if the client is an attacker
        is_attacker = partition_id in ATTACKER_IDS
        return FlowerClient(trainloader=trainloader, valloader=valloader, is_attacker=is_attacker).to_client()

    # Define function to provide fit config with proximal_mu
    def fit_config(rnd: int):
        """Return training configuration dict for each round."""
        return {"proximal_mu": 0.1}  # Set proximal_mu value

    # Define custom strategy to log metrics
    class CustomFedProx(FedProx):  # Changed from CustomFedAvg to CustomFedProx and FedProx
        def __init__(self, *args, **kwargs):
            self.rounds_list = kwargs.pop('rounds_list')
            self.accuracy_list = kwargs.pop('accuracy_list')
            self.kappa_list = kwargs.pop('kappa_list')
            self.f1_list = kwargs.pop('f1_list')
            self.roc_auc_list = kwargs.pop('roc_auc_list')
            proximal_mu = kwargs.pop('proximal_mu', 0.1)  # Extract proximal_mu
            super().__init__(*args, proximal_mu=proximal_mu, **kwargs)  # Pass proximal_mu to FedProx

        def aggregate_evaluate(
            self,
            rnd: int,
            results: List[Tuple[ClientProxy, EvaluateRes]],
            failures: List[BaseException],
        ):
            """Aggregate evaluation results using weighted average and log metrics per round."""
            if not results:
                return None, {}

            # Use weighted average to aggregate metrics
            num_examples_total = sum([r[1].num_examples for r in results])

            # Initialize sums
            accuracy_sum = 0.0
            kappa_sum = 0.0
            f1_sum = 0.0
            roc_auc_sum = 0.0
            roc_auc_weight = 0

            for _, evaluate_res in results:
                accuracy_sum += evaluate_res.metrics.get("accuracy", 0.0) * evaluate_res.num_examples
                kappa_sum += evaluate_res.metrics.get("kappa", 0.0) * evaluate_res.num_examples
                f1_sum += evaluate_res.metrics.get("f1_score", 0.0) * evaluate_res.num_examples
                roc_auc = evaluate_res.metrics.get("roc_auc", float('nan'))
                if not np.isnan(roc_auc):
                    roc_auc_sum += roc_auc * evaluate_res.num_examples
                    roc_auc_weight += evaluate_res.num_examples

            # Compute weighted averages
            accuracy = accuracy_sum / num_examples_total
            kappa = kappa_sum / num_examples_total
            f1 = f1_sum / num_examples_total
            roc_auc = roc_auc_sum / roc_auc_weight if roc_auc_weight > 0 else float('nan')

            # Log metrics
            log(INFO, f"Round {rnd} evaluation metrics:")
            log(INFO, f"Accuracy: {accuracy:.4f}")
            log(INFO, f"Kappa: {kappa:.4f}")
            log(INFO, f"F1 Score: {f1:.4f}")
            if not np.isnan(roc_auc):
                log(INFO, f"ROC AUC: {roc_auc:.4f}")
            else:
                log(INFO, f"ROC AUC: Undefined (only one class present in y_true)")

            # Store metrics
            self.rounds_list.append(rnd)
            self.accuracy_list.append(accuracy)
            self.kappa_list.append(kappa)
            self.f1_list.append(f1)
            self.roc_auc_list.append(roc_auc if not np.isnan(roc_auc) else 0.0)

            # Return aggregated loss and metrics
            return super().aggregate_evaluate(rnd, results, failures)

    # Define the server function
    def server_fn(context: Context):
        # Instantiate the model
        model = Net(num_classes=10)
        ndarrays = get_params(model)
        # Convert model parameters to flwr.common.Parameters
        global_model_init = ndarrays_to_parameters(ndarrays)

        # Define the strategy with FedProx parameters
        strategy = CustomFedProx(
            fraction_fit=1.0,        # All clients participate in training
            fraction_evaluate=1.0,   # All clients participate in evaluation
            initial_parameters=global_model_init,  # Initialized global model
            rounds_list=rounds_list,
            accuracy_list=accuracy_list,
            kappa_list=kappa_list,
            f1_list=f1_list,
            roc_auc_list=roc_auc_list,
            proximal_mu=0.1,  # Proximal term coefficient for FedProx
            on_fit_config_fn=fit_config  # Function to provide fit config
        )

        # Construct ServerConfig
        config = ServerConfig(num_rounds=NUM_ROUNDS)

        # Wrap everything into a ServerAppComponents object
        return ServerAppComponents(strategy=strategy, config=config)

    # Create your ServerApp and ClientApp
    server_app = ServerApp(server_fn=server_fn)
    from flwr.client import ClientApp
    client_app = ClientApp(client_fn=client_fn)

    # Run the simulation
    run_simulation(
        server_app=server_app,
        client_app=client_app,
        num_supernodes=NUM_CLIENTS,
        backend_name="ray",
        verbose_logging=True,
    )

    # After the simulation, collect the metrics
    metrics = {
        "rounds": rounds_list,
        "accuracy": accuracy_list,
        "kappa": kappa_list,
        "f1_score": f1_list,
        "roc_auc": roc_auc_list,
    }

    return metrics

# Function to run all scenarios
def run_all_scenarios():
    scenarios = [
        #{"name": "Baseline_IID", "ATTACKER_IDS": [], "USE_IID": True},
        #{"name": "One_Attacker_IID", "ATTACKER_IDS": [0], "USE_IID": True},
        #{"name": "Two_Attackers_IID", "ATTACKER_IDS": [0, 1], "USE_IID": True},
        #{"name": "Baseline_NonIID", "ATTACKER_IDS": [], "USE_IID": False},
        #{"name": "One_Attacker_NonIID", "ATTACKER_IDS": [0], "USE_IID": False},
        {"name": "Two_Attackers_NonIID", "ATTACKER_IDS": [0, 1], "USE_IID": False},
    ]

    results = {}

    for scenario in scenarios:
        print(f"\nRunning Scenario: {scenario['name']}")
        metrics = run_simulation_scenario(scenario["ATTACKER_IDS"], scenario["USE_IID"])
        results[scenario["name"]] = metrics

        # Plot the metrics
        plt.figure(figsize=(12, 8))

        plt.subplot(2, 2, 1)
        plt.plot(metrics["rounds"], metrics["accuracy"], marker='o', color='blue')
        plt.title(f"Accuracy Over Rounds ({scenario['name']})")
        plt.xlabel('Round')
        plt.ylabel('Accuracy')
        plt.grid(True)

        plt.subplot(2, 2, 2)
        plt.plot(metrics["rounds"], metrics["kappa"], marker='o', color='green')
        plt.title(f"Kappa Over Rounds ({scenario['name']})")
        plt.xlabel('Round')
        plt.ylabel('Kappa')
        plt.grid(True)

        plt.subplot(2, 2, 3)
        plt.plot(metrics["rounds"], metrics["f1_score"], marker='o', color='red')
        plt.title(f"F1 Score Over Rounds ({scenario['name']})")
        plt.xlabel('Round')
        plt.ylabel("F1 Score")
        plt.grid(True)

        plt.subplot(2, 2, 4)
        plt.plot(metrics["rounds"], metrics["roc_auc"], marker='o', color='purple')
        plt.title(f"ROC AUC Over Rounds ({scenario['name']})")
        plt.xlabel('Round')
        plt.ylabel("ROC AUC")
        plt.grid(True)

        plt.tight_layout()
        plt.show()

        # Save metrics to CSV
        df = pd.DataFrame(metrics)
        df.to_csv(f"{scenario['name']}_metrics.csv", index=False)

    return results

# Run all scenarios
#results = run_all_scenarios()

# %%
import itertools
import random

# Define ranges for NOISE_MULTIPLIER and CLIPPING_NORM
NOISE_MULTIPLIER_RANGE = [0.1, 0.5, 1.0, 2.0]  # Example values
CLIPPING_NORM_RANGE = [5.0, 10.0, 20.0, 50.0]  # Example values

# Define the number of random samples to test
NUM_RANDOM_SAMPLES = 10

# Generate all possible combinations
parameter_combinations = list(itertools.product(NOISE_MULTIPLIER_RANGE, CLIPPING_NORM_RANGE))

# Randomly sample a subset of combinations
random_combinations = random.sample(parameter_combinations, NUM_RANDOM_SAMPLES)

# Placeholder for results
grid_search_results = []

# Perform the randomized grid search
for noise_multiplier, clipping_norm in random_combinations:
    print(f"\nTesting with NOISE_MULTIPLIER={noise_multiplier}, CLIPPING_NORM={clipping_norm}")

    # Update the constants
    NOISE_MULTIPLIER = noise_multiplier
    CLIPPING_NORM = clipping_norm

    # Run the simulation with the current parameters
    results = run_all_scenarios()

    # Collect performance metrics (e.g., final accuracy or F1 score)
    for scenario_name, metrics in results.items():
        final_accuracy = metrics["accuracy"][-1]  # Take the accuracy from the last round
        grid_search_results.append({
            "Scenario": scenario_name,
            "NOISE_MULTIPLIER": noise_multiplier,
            "CLIPPING_NORM": clipping_norm,
            "Final_Accuracy": final_accuracy
        })

# Analyze results and find the best parameters
df_results = pd.DataFrame(grid_search_results)
best_result = df_results.loc[df_results["Final_Accuracy"].idxmax()]

print("\nBest Parameters:")
print(best_result)

# Save results to a CSV file
df_results.to_csv("grid_search_results.csv", index=False)
# Out:
# DEBUG 2024-11-23 23:40:17,746:     Asyncio event loop already running.
# DEBUG 2024-11-23 23:40:17,747:     Logger propagate set to False
# DEBUG 2024-11-23 23:40:17,748:     Pre-registering run with id 1400711239594528788
# DEBUG 2024-11-23 23:40:17,749:     Using InMemoryState
# DEBUG 2024-11-23 23:40:17,750:     Using InMemoryState
# DEBUG 2024-11-23 23:40:17,751:     Buffer time delay: 5s
# INFO 2024-11-23 23:40:17,755:      Starting Flower ServerApp, config: num_rounds=50, no round_timeout
# INFO 2024-11-23 23:40:17,755:
# INFO 2024-11-23 23:40:17,756:      [INIT]
# INFO 2024-11-23 23:40:17,756:      Using initial global parameters provided by strategy
# INFO 2024-11-23 23:40:17,756:      Starting evaluation of initial global parameters
# INFO 2024-11-23 23:40:17,757:      Evaluation returned no results (`None`)
# INFO 2024-11-23 23:40:17,757:
# INFO 2024-11-23 23:40:17,758:      [ROUND 1]
# Testing with NOISE_MULTIPLIER=0.1, CLIPPING_NORM=50.0
#
# Running Scenario: Two_Attackers_NonIID
# DEBUG 2024-11-23 23:40:22,752:     Using InMemoryState
# DEBUG 2024-11-23 23:40:22,753:     Registered 5 nodes
# DEBUG 2024-11-23 23:40:22,754:     Supported backends: ['ray']
# DEBUG 2024-11-23 23:40:22,755:     Initialising: RayBackend
# DEBUG 2024-11-23 23:40:22,755:     Backend config: {'init_args': {}, 'client_resources': {'num_cpus': 2, 'num_gpus': 0}, 'actor': {'tensorflow': 0}}
# 2024-11-23 23:40:23,451	INFO worker.py:1819 -- Started a local Ray instance.
# INFO 2024-11-23 23:40:24,022:      configure_fit: strategy sampled 2 clients (out of 5)
# DEBUG 2024-11-23 23:40:24,037:     Constructed ActorPool with: 16 actors
# DEBUG 2024-11-23 23:40:24,038:     Using InMemoryState
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead.
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args]
# INFO 2024-11-23 23:40:34,144:      aggregate_fit: received 2 results and 0 failures
# WARNING 2024-11-23 23:40:34,147:   No fit_metrics_aggregation_fn provided
# INFO 2024-11-23 23:40:34,147:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 3x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 3x across cluster]
# INFO 2024-11-23 23:40:41,761:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:40:41,762:      Round 1 evaluation metrics:
# INFO 2024-11-23 23:40:41,763:      Accuracy: 0.1293
# INFO 2024-11-23 23:40:41,763:      Kappa: 0.0333
# INFO 2024-11-23 23:40:41,764:      F1 Score: 0.0618
# INFO 2024-11-23 23:40:41,764:      ROC AUC: 0.6700
# WARNING 2024-11-23 23:40:41,765:   No evaluate_metrics_aggregation_fn provided
# INFO 2024-11-23 23:40:41,765:
# INFO 2024-11-23 23:40:41,765:      [ROUND 2]
# INFO 2024-11-23 23:40:41,766:      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 4x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 4x across cluster]
# INFO 2024-11-23 23:40:47,494:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:40:47,497:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 5x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 5x across cluster]
# INFO 2024-11-23 23:40:50,609:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:40:50,609:      Round 2 evaluation metrics:
# INFO 2024-11-23 23:40:50,610:      Accuracy: 0.2275
# INFO 2024-11-23 23:40:50,610:      Kappa: 0.1317
# INFO 2024-11-23 23:40:50,611:      F1 Score: 0.1363
# INFO 2024-11-23 23:40:50,611:      ROC AUC: 0.7339
# INFO 2024-11-23 23:40:50,611:
# INFO 2024-11-23 23:40:50,612:      [ROUND 3]
# INFO 2024-11-23 23:40:50,612:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:40:55,824:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:40:55,827:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011652) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011652)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:40:58,734:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:40:58,734:      Round 3 evaluation metrics:
# INFO 2024-11-23 23:40:58,735:      Accuracy: 0.2690
# INFO 2024-11-23 23:40:58,735:      Kappa: 0.1776
# INFO 2024-11-23 23:40:58,735:      F1 Score: 0.1847
# INFO 2024-11-23 23:40:58,736:      ROC AUC: 0.7598
# INFO 2024-11-23 23:40:58,737:
# INFO 2024-11-23 23:40:58,737:      [ROUND 4]
# INFO 2024-11-23 23:40:58,738:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:03,949:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:03,953:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:06,660:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:06,660:      Round 4 evaluation metrics:
# INFO 2024-11-23 23:41:06,661:      Accuracy: 0.2814
# INFO 2024-11-23 23:41:06,661:      Kappa: 0.1908
# INFO 2024-11-23 23:41:06,661:      F1 Score: 0.1990
# INFO 2024-11-23 23:41:06,662:      ROC AUC: 0.7702
# INFO 2024-11-23 23:41:06,662:
# INFO 2024-11-23 23:41:06,662:      [ROUND 5]
# INFO 2024-11-23 23:41:06,662:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:11,975:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:11,978:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:15,085:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:15,086:      Round 5 evaluation metrics:
# INFO 2024-11-23 23:41:15,086:      Accuracy: 0.3182
# INFO 2024-11-23 23:41:15,087:      Kappa: 0.2311
# INFO 2024-11-23 23:41:15,087:      F1 Score: 0.2250
# INFO 2024-11-23 23:41:15,087:      ROC AUC: 0.7834
# INFO 2024-11-23 23:41:15,088:
# INFO 2024-11-23 23:41:15,088:      [ROUND 6]
# INFO 2024-11-23 23:41:15,088:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:20,401:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:20,404:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:23,712:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:23,712:      Round 6 evaluation metrics:
# INFO 2024-11-23 23:41:23,713:      Accuracy: 0.3340
# INFO 2024-11-23 23:41:23,713:      Kappa: 0.2470
# INFO 2024-11-23 23:41:23,713:      F1 Score: 0.2384
# INFO 2024-11-23 23:41:23,714:      ROC AUC: 0.7909
# INFO 2024-11-23 23:41:23,714:
# INFO 2024-11-23 23:41:23,715:      [ROUND 7]
# INFO 2024-11-23 23:41:23,715:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:28,927:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:28,930:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:32,137:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:32,138:      Round 7 evaluation metrics:
# INFO 2024-11-23 23:41:32,138:      Accuracy: 0.3328
# INFO 2024-11-23 23:41:32,138:      Kappa: 0.2473
# INFO 2024-11-23 23:41:32,139:      F1 Score: 0.2468
# INFO 2024-11-23 23:41:32,139:      ROC AUC: 0.7947
# INFO 2024-11-23 23:41:32,139:
# INFO 2024-11-23 23:41:32,140:      [ROUND 8]
# INFO 2024-11-23 23:41:32,140:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:37,451:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:37,454:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:40,361:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:40,362:      Round 8 evaluation metrics:
# INFO 2024-11-23 23:41:40,362:      Accuracy: 0.3472
# INFO 2024-11-23 23:41:40,363:      Kappa: 0.2634
# INFO 2024-11-23 23:41:40,363:      F1 Score: 0.2792
# INFO 2024-11-23 23:41:40,363:      ROC AUC: 0.7948
# INFO 2024-11-23 23:41:40,364:
# INFO 2024-11-23 23:41:40,364:      [ROUND 9]
# INFO 2024-11-23 23:41:40,365:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:45,483:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:45,486:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:49,001:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:49,001:      Round 9 evaluation metrics:
# INFO 2024-11-23 23:41:49,002:      Accuracy: 0.3734
# INFO 2024-11-23 23:41:49,002:      Kappa: 0.2931
# INFO 2024-11-23 23:41:49,002:      F1 Score: 0.3128
# INFO 2024-11-23 23:41:49,003:      ROC AUC: 0.8012
# INFO 2024-11-23 23:41:49,003:
# INFO 2024-11-23 23:41:49,003:      [ROUND 10]
# INFO 2024-11-23 23:41:49,004:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:41:54,317:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:41:54,320:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:41:57,329:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:41:57,329:      Round 10 evaluation metrics:
# INFO 2024-11-23 23:41:57,330:      Accuracy: 0.3646
# INFO 2024-11-23 23:41:57,330:      Kappa: 0.2830
# INFO 2024-11-23 23:41:57,330:      F1 Score: 0.2991
# INFO 2024-11-23 23:41:57,331:      ROC AUC: 0.8025
# INFO 2024-11-23 23:41:57,331:
# INFO 2024-11-23 23:41:57,332:      [ROUND 11]
# INFO 2024-11-23 23:41:57,333:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:02,846:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:02,849:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:05,756:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:05,757:      Round 11 evaluation metrics:
# INFO 2024-11-23 23:42:05,758:      Accuracy: 0.3450
# INFO 2024-11-23 23:42:05,758:      Kappa: 0.2613
# INFO 2024-11-23 23:42:05,758:      F1 Score: 0.2657
# INFO 2024-11-23 23:42:05,759:      ROC AUC: 0.8053
# INFO 2024-11-23 23:42:05,759:
# INFO 2024-11-23 23:42:05,759:      [ROUND 12]
# INFO 2024-11-23 23:42:05,760:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:11,172:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:11,174:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:14,182:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:14,183:      Round 12 evaluation metrics:
# INFO 2024-11-23 23:42:14,184:      Accuracy: 0.3756
# INFO 2024-11-23 23:42:14,184:      Kappa: 0.2948
# INFO 2024-11-23 23:42:14,184:      F1 Score: 0.3175
# INFO 2024-11-23 23:42:14,185:      ROC AUC: 0.8104
# INFO 2024-11-23 23:42:14,185:
# INFO 2024-11-23 23:42:14,185:      [ROUND 13]
# INFO 2024-11-23 23:42:14,185:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:19,698:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:19,702:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:22,810:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:22,810:      Round 13 evaluation metrics:
# INFO 2024-11-23 23:42:22,811:      Accuracy: 0.3920
# INFO 2024-11-23 23:42:22,811:      Kappa: 0.3122
# INFO 2024-11-23 23:42:22,811:      F1 Score: 0.3272
# INFO 2024-11-23 23:42:22,812:      ROC AUC: 0.8108
# INFO 2024-11-23 23:42:22,812:
# INFO 2024-11-23 23:42:22,812:      [ROUND 14]
# INFO 2024-11-23 23:42:22,813:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:28,326:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:28,329:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011652) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011652)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:31,737:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:31,738:      Round 14 evaluation metrics:
# INFO 2024-11-23 23:42:31,738:      Accuracy: 0.3772
# INFO 2024-11-23 23:42:31,739:      Kappa: 0.2966
# INFO 2024-11-23 23:42:31,739:      F1 Score: 0.3186
# INFO 2024-11-23 23:42:31,739:      ROC AUC: 0.8132
# INFO 2024-11-23 23:42:31,740:
# INFO 2024-11-23 23:42:31,740:      [ROUND 15]
# INFO 2024-11-23 23:42:31,741:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:37,054:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:37,057:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:40,164:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:40,165:      Round 15 evaluation metrics:
# INFO 2024-11-23 23:42:40,165:      Accuracy: 0.3836
# INFO 2024-11-23 23:42:40,165:      Kappa: 0.3028
# INFO 2024-11-23 23:42:40,166:      F1 Score: 0.3185
# INFO 2024-11-23 23:42:40,166:      ROC AUC: 0.8195
# INFO 2024-11-23 23:42:40,166:
# INFO 2024-11-23 23:42:40,167:      [ROUND 16]
# INFO 2024-11-23 23:42:40,167:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:45,489:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:45,492:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:48,511:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:48,512:      Round 16 evaluation metrics:
# INFO 2024-11-23 23:42:48,512:      Accuracy: 0.4231
# INFO 2024-11-23 23:42:48,512:      Kappa: 0.3452
# INFO 2024-11-23 23:42:48,512:      F1 Score: 0.3621
# INFO 2024-11-23 23:42:48,514:      ROC AUC: 0.8239
# INFO 2024-11-23 23:42:48,514:
# INFO 2024-11-23 23:42:48,514:      [ROUND 17]
# INFO 2024-11-23 23:42:48,515:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:42:53,726:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:42:53,731:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011652) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011652)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:42:56,880:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:42:56,880:      Round 17 evaluation metrics:
# INFO 2024-11-23 23:42:56,881:      Accuracy: 0.3934
# INFO 2024-11-23 23:42:56,881:      Kappa: 0.3142
# INFO 2024-11-23 23:42:56,882:      F1 Score: 0.3394
# INFO 2024-11-23 23:42:56,882:      ROC AUC: 0.8182
# INFO 2024-11-23 23:42:56,882:
# INFO 2024-11-23 23:42:56,883:      [ROUND 18]
# INFO 2024-11-23 23:42:56,883:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:02,099:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:02,102:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:05,110:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:05,111:      Round 18 evaluation metrics:
# INFO 2024-11-23 23:43:05,111:      Accuracy: 0.3556
# INFO 2024-11-23 23:43:05,112:      Kappa: 0.2742
# INFO 2024-11-23 23:43:05,112:      F1 Score: 0.2892
# INFO 2024-11-23 23:43:05,113:      ROC AUC: 0.8162
# INFO 2024-11-23 23:43:05,113:
# INFO 2024-11-23 23:43:05,113:      [ROUND 19]
# INFO 2024-11-23 23:43:05,114:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:10,526:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:10,529:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:13,436:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:13,437:      Round 19 evaluation metrics:
# INFO 2024-11-23 23:43:13,437:      Accuracy: 0.3752
# INFO 2024-11-23 23:43:13,438:      Kappa: 0.2949
# INFO 2024-11-23 23:43:13,438:      F1 Score: 0.3175
# INFO 2024-11-23 23:43:13,438:      ROC AUC: 0.8232
# INFO 2024-11-23 23:43:13,439:
# INFO 2024-11-23 23:43:13,439:      [ROUND 20]
# INFO 2024-11-23 23:43:13,440:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:18,653:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:18,657:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:21,765:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:21,765:      Round 20 evaluation metrics:
# INFO 2024-11-23 23:43:21,765:      Accuracy: 0.3712
# INFO 2024-11-23 23:43:21,766:      Kappa: 0.2895
# INFO 2024-11-23 23:43:21,766:      F1 Score: 0.3144
# INFO 2024-11-23 23:43:21,767:      ROC AUC: 0.8196
# INFO 2024-11-23 23:43:21,767:
# INFO 2024-11-23 23:43:21,767:      [ROUND 21]
# INFO 2024-11-23 23:43:21,767:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:26,779:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:26,782:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:29,789:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:29,790:      Round 21 evaluation metrics:
# INFO 2024-11-23 23:43:29,790:      Accuracy: 0.4124
# INFO 2024-11-23 23:43:29,790:      Kappa: 0.3347
# INFO 2024-11-23 23:43:29,790:      F1 Score: 0.3538
# INFO 2024-11-23 23:43:29,791:      ROC AUC: 0.8245
# INFO 2024-11-23 23:43:29,792:
# INFO 2024-11-23 23:43:29,792:      [ROUND 22]
# INFO 2024-11-23 23:43:29,792:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:35,004:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:35,007:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:38,315:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:38,315:      Round 22 evaluation metrics:
# INFO 2024-11-23 23:43:38,316:      Accuracy: 0.4195
# INFO 2024-11-23 23:43:38,317:      Kappa: 0.3422
# INFO 2024-11-23 23:43:38,317:      F1 Score: 0.3688
# INFO 2024-11-23 23:43:38,318:      ROC AUC: 0.8268
# INFO 2024-11-23 23:43:38,318:
# INFO 2024-11-23 23:43:38,318:      [ROUND 23]
# INFO 2024-11-23 23:43:38,319:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:44,032:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:44,037:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011653) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011653)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:47,245:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:47,245:      Round 23 evaluation metrics:
# INFO 2024-11-23 23:43:47,246:      Accuracy: 0.4082
# INFO 2024-11-23 23:43:47,246:      Kappa: 0.3306
# INFO 2024-11-23 23:43:47,247:      F1 Score: 0.3570
# INFO 2024-11-23 23:43:47,247:      ROC AUC: 0.8242
# INFO 2024-11-23 23:43:47,247:
# INFO 2024-11-23 23:43:47,248:      [ROUND 24]
# INFO 2024-11-23 23:43:47,249:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:43:52,562:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:43:52,564:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:43:55,594:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:43:55,594:      Round 24 evaluation metrics:
# INFO 2024-11-23 23:43:55,595:      Accuracy: 0.3994
# INFO 2024-11-23 23:43:55,595:      Kappa: 0.3201
# INFO 2024-11-23 23:43:55,595:      F1 Score: 0.3525
# INFO 2024-11-23 23:43:55,596:      ROC AUC: 0.8246
# INFO 2024-11-23 23:43:55,596:
# INFO 2024-11-23 23:43:55,596:      [ROUND 25]
# INFO 2024-11-23 23:43:55,597:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:00,808:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:00,811:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011653) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011653)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:03,918:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:03,918:      Round 25 evaluation metrics:
# INFO 2024-11-23 23:44:03,919:      Accuracy: 0.4164
# INFO 2024-11-23 23:44:03,919:      Kappa: 0.3384
# INFO 2024-11-23 23:44:03,920:      F1 Score: 0.3617
# INFO 2024-11-23 23:44:03,920:      ROC AUC: 0.8257
# INFO 2024-11-23 23:44:03,920:
# INFO 2024-11-23 23:44:03,921:      [ROUND 26]
# INFO 2024-11-23 23:44:03,921:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:09,333:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:09,337:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:12,345:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:12,346:      Round 26 evaluation metrics:
# INFO 2024-11-23 23:44:12,346:      Accuracy: 0.4199
# INFO 2024-11-23 23:44:12,347:      Kappa: 0.3432
# INFO 2024-11-23 23:44:12,347:      F1 Score: 0.3679
# INFO 2024-11-23 23:44:12,348:      ROC AUC: 0.8281
# INFO 2024-11-23 23:44:12,348:
# INFO 2024-11-23 23:44:12,349:      [ROUND 27]
# INFO 2024-11-23 23:44:12,349:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:17,560:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:17,563:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:20,570:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:20,570:      Round 27 evaluation metrics:
# INFO 2024-11-23 23:44:20,571:      Accuracy: 0.3872
# INFO 2024-11-23 23:44:20,571:      Kappa: 0.3068
# INFO 2024-11-23 23:44:20,571:      F1 Score: 0.3303
# INFO 2024-11-23 23:44:20,572:      ROC AUC: 0.8253
# INFO 2024-11-23 23:44:20,572:
# INFO 2024-11-23 23:44:20,573:      [ROUND 28]
# INFO 2024-11-23 23:44:20,573:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:25,986:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:25,989:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:28,796:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:28,796:      Round 28 evaluation metrics:
# INFO 2024-11-23 23:44:28,797:      Accuracy: 0.3812
# INFO 2024-11-23 23:44:28,797:      Kappa: 0.3006
# INFO 2024-11-23 23:44:28,797:      F1 Score: 0.3299
# INFO 2024-11-23 23:44:28,798:      ROC AUC: 0.8237
# INFO 2024-11-23 23:44:28,798:
# INFO 2024-11-23 23:44:28,798:      [ROUND 29]
# INFO 2024-11-23 23:44:28,799:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:34,110:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:34,113:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:37,220:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:37,220:      Round 29 evaluation metrics:
# INFO 2024-11-23 23:44:37,221:      Accuracy: 0.4633
# INFO 2024-11-23 23:44:37,221:      Kappa: 0.3918
# INFO 2024-11-23 23:44:37,221:      F1 Score: 0.4065
# INFO 2024-11-23 23:44:37,222:      ROC AUC: 0.8327
# INFO 2024-11-23 23:44:37,222:
# INFO 2024-11-23 23:44:37,222:      [ROUND 30]
# INFO 2024-11-23 23:44:37,223:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:42,935:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:42,939:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:46,047:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:46,048:      Round 30 evaluation metrics:
# INFO 2024-11-23 23:44:46,048:      Accuracy: 0.4767
# INFO 2024-11-23 23:44:46,048:      Kappa: 0.4060
# INFO 2024-11-23 23:44:46,049:      F1 Score: 0.4185
# INFO 2024-11-23 23:44:46,049:      ROC AUC: 0.8353
# INFO 2024-11-23 23:44:46,049:
# INFO 2024-11-23 23:44:46,050:      [ROUND 31]
# INFO 2024-11-23 23:44:46,050:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:51,060:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:51,063:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:44:53,988:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:44:53,988:      Round 31 evaluation metrics:
# INFO 2024-11-23 23:44:53,989:      Accuracy: 0.4515
# INFO 2024-11-23 23:44:53,989:      Kappa: 0.3779
# INFO 2024-11-23 23:44:53,990:      F1 Score: 0.3961
# INFO 2024-11-23 23:44:53,990:      ROC AUC: 0.8369
# INFO 2024-11-23 23:44:53,990:
# INFO 2024-11-23 23:44:53,991:      [ROUND 32]
# INFO 2024-11-23 23:44:53,992:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:44:59,204:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:44:59,207:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011652) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011652)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:02,114:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:02,115:      Round 32 evaluation metrics:
# INFO 2024-11-23 23:45:02,115:      Accuracy: 0.4683
# INFO 2024-11-23 23:45:02,115:      Kappa: 0.3963
# INFO 2024-11-23 23:45:02,116:      F1 Score: 0.4109
# INFO 2024-11-23 23:45:02,116:      ROC AUC: 0.8412
# INFO 2024-11-23 23:45:02,117:
# INFO 2024-11-23 23:45:02,117:      [ROUND 33]
# INFO 2024-11-23 23:45:02,117:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:07,429:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:07,433:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:10,439:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:10,440:      Round 33 evaluation metrics:
# INFO 2024-11-23 23:45:10,440:      Accuracy: 0.4739
# INFO 2024-11-23 23:45:10,441:      Kappa: 0.4030
# INFO 2024-11-23 23:45:10,441:      F1 Score: 0.4169
# INFO 2024-11-23 23:45:10,441:      ROC AUC: 0.8385
# INFO 2024-11-23 23:45:10,441:
# INFO 2024-11-23 23:45:10,442:      [ROUND 34]
# INFO 2024-11-23 23:45:10,442:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:15,653:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:15,656:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:18,562:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:18,563:      Round 34 evaluation metrics:
# INFO 2024-11-23 23:45:18,563:      Accuracy: 0.4441
# INFO 2024-11-23 23:45:18,564:      Kappa: 0.3697
# INFO 2024-11-23 23:45:18,564:      F1 Score: 0.3826
# INFO 2024-11-23 23:45:18,564:      ROC AUC: 0.8303
# INFO 2024-11-23 23:45:18,565:
# INFO 2024-11-23 23:45:18,565:      [ROUND 35]
# INFO 2024-11-23 23:45:18,566:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:24,078:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:24,080:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:26,987:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:26,987:      Round 35 evaluation metrics:
# INFO 2024-11-23 23:45:26,988:      Accuracy: 0.3994
# INFO 2024-11-23 23:45:26,988:      Kappa: 0.3200
# INFO 2024-11-23 23:45:26,989:      F1 Score: 0.3438
# INFO 2024-11-23 23:45:26,989:      ROC AUC: 0.8235
# INFO 2024-11-23 23:45:26,990:
# INFO 2024-11-23 23:45:26,990:      [ROUND 36]
# INFO 2024-11-23 23:45:26,990:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:32,002:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:32,006:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:35,012:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:35,013:      Round 36 evaluation metrics:
# INFO 2024-11-23 23:45:35,013:      Accuracy: 0.4323
# INFO 2024-11-23 23:45:35,014:      Kappa: 0.3569
# INFO 2024-11-23 23:45:35,014:      F1 Score: 0.3791
# INFO 2024-11-23 23:45:35,014:      ROC AUC: 0.8343
# INFO 2024-11-23 23:45:35,015:
# INFO 2024-11-23 23:45:35,015:      [ROUND 37]
# INFO 2024-11-23 23:45:35,016:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:40,427:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:40,430:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011651) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011651)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:43,537:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:43,538:      Round 37 evaluation metrics:
# INFO 2024-11-23 23:45:43,538:      Accuracy: 0.4603
# INFO 2024-11-23 23:45:43,539:      Kappa: 0.3876
# INFO 2024-11-23 23:45:43,539:      F1 Score: 0.3985
# INFO 2024-11-23 23:45:43,539:      ROC AUC: 0.8402
# INFO 2024-11-23 23:45:43,540:
# INFO 2024-11-23 23:45:43,540:      [ROUND 38]
# INFO 2024-11-23 23:45:43,540:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:49,453:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:49,456:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:45:52,480:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:45:52,480:      Round 38 evaluation metrics:
# INFO 2024-11-23 23:45:52,481:      Accuracy: 0.4018
# INFO 2024-11-23 23:45:52,481:      Kappa: 0.3230
# INFO 2024-11-23 23:45:52,481:      F1 Score: 0.3498
# INFO 2024-11-23 23:45:52,482:      ROC AUC: 0.8280
# INFO 2024-11-23 23:45:52,482:
# INFO 2024-11-23 23:45:52,482:      [ROUND 39]
# INFO 2024-11-23 23:45:52,483:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:45:57,799:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:45:57,802:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011654) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011654)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:46:00,809:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:46:00,810:      Round 39 evaluation metrics:
# INFO 2024-11-23 23:46:00,810:      Accuracy: 0.4501
# INFO 2024-11-23 23:46:00,811:      Kappa: 0.3770
# INFO 2024-11-23 23:46:00,811:      F1 Score: 0.3988
# INFO 2024-11-23 23:46:00,811:      ROC AUC: 0.8311
# INFO 2024-11-23 23:46:00,812:
# INFO 2024-11-23 23:46:00,812:      [ROUND 40]
# INFO 2024-11-23 23:46:00,812:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:46:05,923:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:46:05,927:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011652) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011652)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:46:08,934:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:46:08,935:      Round 40 evaluation metrics:
# INFO 2024-11-23 23:46:08,935:      Accuracy: 0.4261
# INFO 2024-11-23 23:46:08,936:      Kappa: 0.3513
# INFO 2024-11-23 23:46:08,936:      F1 Score: 0.3734
# INFO 2024-11-23 23:46:08,936:      ROC AUC: 0.8273
# INFO 2024-11-23 23:46:08,937:
# INFO 2024-11-23 23:46:08,937:      [ROUND 41]
# INFO 2024-11-23 23:46:08,937:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:46:14,149:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:46:14,152:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:46:17,659:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:46:17,660:      Round 41 evaluation metrics:
# INFO 2024-11-23 23:46:17,660:      Accuracy: 0.4207
# INFO 2024-11-23 23:46:17,660:      Kappa: 0.3445
# INFO 2024-11-23 23:46:17,661:      F1 Score: 0.3752
# INFO 2024-11-23 23:46:17,661:      ROC AUC: 0.8302
# INFO 2024-11-23 23:46:17,662:
# INFO 2024-11-23 23:46:17,662:      [ROUND 42]
# INFO 2024-11-23 23:46:17,662:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:46:22,774:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:46:22,777:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011649) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011649)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:46:25,783:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:46:25,783:      Round 42 evaluation metrics:
# INFO 2024-11-23 23:46:25,784:      Accuracy: 0.4533
# INFO 2024-11-23 23:46:25,784:      Kappa: 0.3803
# INFO 2024-11-23 23:46:25,784:      F1 Score: 0.3992
# INFO 2024-11-23 23:46:25,785:      ROC AUC: 0.8386
# INFO 2024-11-23 23:46:25,786:
# INFO 2024-11-23 23:46:25,786:      [ROUND 43]
# INFO 2024-11-23 23:46:25,786:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:46:30,698:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:46:30,701:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1011653) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1011653)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-23 23:46:33,707:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-23 23:46:33,708:      Round 43 evaluation metrics:
# INFO 2024-11-23 23:46:33,708:      Accuracy: 0.4034
# INFO 2024-11-23 23:46:33,709:      Kappa: 0.3241
# INFO 2024-11-23 23:46:33,709:      F1 Score: 0.3481
# INFO 2024-11-23 23:46:33,709:      ROC AUC: 0.8261
# INFO 2024-11-23 23:46:33,710:
# INFO 2024-11-23 23:46:33,710:      [ROUND 44]
# INFO 2024-11-23 23:46:33,711:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-23 23:46:38,922:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-23 23:46:38,925:      configure_evaluate: strategy sampled 5 clients (out of 5)
# ...
# INFO 2024-11-24 00:50:24,467:
# INFO 2024-11-24 00:50:24,467:      [ROUND 40]
# INFO 2024-11-24 00:50:24,467:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:50:29,479:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:50:29,482:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105973) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105973)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:50:32,288:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:50:32,289:      Round 40 evaluation metrics:
# INFO 2024-11-24 00:50:32,289:      Accuracy: 0.4104
# INFO 2024-11-24 00:50:32,290:      Kappa: 0.3323
# INFO 2024-11-24 00:50:32,290:      F1 Score: 0.3608
# INFO 2024-11-24 00:50:32,290:      ROC AUC: 0.8380
# INFO 2024-11-24 00:50:32,290:
# INFO 2024-11-24 00:50:32,291:      [ROUND 41]
# INFO 2024-11-24 00:50:32,291:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:50:37,804:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:50:37,806:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105974) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105974)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:50:40,713:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:50:40,714:      Round 41 evaluation metrics:
# INFO 2024-11-24 00:50:40,714:      Accuracy: 0.4537
# INFO 2024-11-24 00:50:40,714:      Kappa: 0.3793
# INFO 2024-11-24 00:50:40,715:      F1 Score: 0.3812
# INFO 2024-11-24 00:50:40,715:      ROC AUC: 0.8500
# INFO 2024-11-24 00:50:40,715:
# INFO 2024-11-24 00:50:40,716:      [ROUND 42]
# INFO 2024-11-24 00:50:40,716:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:50:46,128:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:50:46,131:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105953) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105953)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:50:48,938:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:50:48,939:      Round 42 evaluation metrics:
# INFO 2024-11-24 00:50:48,939:      Accuracy: 0.4100
# INFO 2024-11-24 00:50:48,940:      Kappa: 0.3317
# INFO 2024-11-24 00:50:48,940:      F1 Score: 0.3452
# INFO 2024-11-24 00:50:48,940:      ROC AUC: 0.8399
# INFO 2024-11-24 00:50:48,941:
# INFO 2024-11-24 00:50:48,941:      [ROUND 43]
# INFO 2024-11-24 00:50:48,941:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:50:53,853:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:50:53,856:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105974) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105974)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:50:56,882:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:50:56,883:      Round 43 evaluation metrics:
# INFO 2024-11-24 00:50:56,883:      Accuracy: 0.3720
# INFO 2024-11-24 00:50:56,884:      Kappa: 0.2905
# INFO 2024-11-24 00:50:56,884:      F1 Score: 0.3193
# INFO 2024-11-24 00:50:56,884:      ROC AUC: 0.8373
# INFO 2024-11-24 00:50:56,885:
# INFO 2024-11-24 00:50:56,885:      [ROUND 44]
# INFO 2024-11-24 00:50:56,885:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:02,203:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:02,206:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105975) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105975)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:05,213:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:05,214:      Round 44 evaluation metrics:
# INFO 2024-11-24 00:51:05,214:      Accuracy: 0.4393
# INFO 2024-11-24 00:51:05,214:      Kappa: 0.3649
# INFO 2024-11-24 00:51:05,215:      F1 Score: 0.3833
# INFO 2024-11-24 00:51:05,215:      ROC AUC: 0.8530
# INFO 2024-11-24 00:51:05,215:
# INFO 2024-11-24 00:51:05,216:      [ROUND 45]
# INFO 2024-11-24 00:51:05,216:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:10,530:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:10,533:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105973) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105973)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:13,443:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:13,443:      Round 45 evaluation metrics:
# INFO 2024-11-24 00:51:13,444:      Accuracy: 0.5233
# INFO 2024-11-24 00:51:13,444:      Kappa: 0.4583
# INFO 2024-11-24 00:51:13,444:      F1 Score: 0.4630
# INFO 2024-11-24 00:51:13,445:      ROC AUC: 0.8635
# INFO 2024-11-24 00:51:13,445:
# INFO 2024-11-24 00:51:13,445:      [ROUND 46]
# INFO 2024-11-24 00:51:13,446:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:18,959:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:18,962:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105953) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105953)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:22,270:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:22,270:      Round 46 evaluation metrics:
# INFO 2024-11-24 00:51:22,270:      Accuracy: 0.5107
# INFO 2024-11-24 00:51:22,271:      Kappa: 0.4442
# INFO 2024-11-24 00:51:22,271:      F1 Score: 0.4529
# INFO 2024-11-24 00:51:22,271:      ROC AUC: 0.8563
# INFO 2024-11-24 00:51:22,272:
# INFO 2024-11-24 00:51:22,273:      [ROUND 47]
# INFO 2024-11-24 00:51:22,273:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:27,786:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:27,789:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105974) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105974)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:30,998:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:30,998:      Round 47 evaluation metrics:
# INFO 2024-11-24 00:51:30,999:      Accuracy: 0.4859
# INFO 2024-11-24 00:51:30,999:      Kappa: 0.4158
# INFO 2024-11-24 00:51:31,000:      F1 Score: 0.4317
# INFO 2024-11-24 00:51:31,000:      ROC AUC: 0.8501
# INFO 2024-11-24 00:51:31,001:
# INFO 2024-11-24 00:51:31,001:      [ROUND 48]
# INFO 2024-11-24 00:51:31,002:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:36,817:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:36,822:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105953) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105953)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:39,729:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:39,730:      Round 48 evaluation metrics:
# INFO 2024-11-24 00:51:39,731:      Accuracy: 0.4391
# INFO 2024-11-24 00:51:39,731:      Kappa: 0.3638
# INFO 2024-11-24 00:51:39,731:      F1 Score: 0.3758
# INFO 2024-11-24 00:51:39,732:      ROC AUC: 0.8495
# INFO 2024-11-24 00:51:39,732:
# INFO 2024-11-24 00:51:39,733:      [ROUND 49]
# INFO 2024-11-24 00:51:39,733:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:44,845:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:44,849:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105953) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105953)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:47,881:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:47,882:      Round 49 evaluation metrics:
# INFO 2024-11-24 00:51:47,882:      Accuracy: 0.4787
# INFO 2024-11-24 00:51:47,883:      Kappa: 0.4081
# INFO 2024-11-24 00:51:47,883:      F1 Score: 0.4182
# INFO 2024-11-24 00:51:47,884:      ROC AUC: 0.8596
# INFO 2024-11-24 00:51:47,885:
# INFO 2024-11-24 00:51:47,885:      [ROUND 50]
# INFO 2024-11-24 00:51:47,885:      configure_fit: strategy sampled 5 clients (out of 5)
# INFO 2024-11-24 00:51:53,300:      aggregate_fit: received 5 results and 0 failures
# INFO 2024-11-24 00:51:53,303:      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=1105953) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 10x across cluster]
# (ClientAppActor pid=1105953)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 10x across cluster]
# INFO 2024-11-24 00:51:56,210:      aggregate_evaluate: received 5 results and 0 failures
# INFO 2024-11-24 00:51:56,211:      Round 50 evaluation metrics:
# INFO 2024-11-24 00:51:56,211:      Accuracy: 0.4369
# INFO 2024-11-24 00:51:56,212:      Kappa: 0.3614
# INFO 2024-11-24 00:51:56,212:      F1 Score: 0.3785
# INFO 2024-11-24 00:51:56,212:      ROC AUC: 0.8475
# INFO 2024-11-24 00:51:56,213:
# INFO 2024-11-24 00:51:56,213:      [SUMMARY]
# INFO 2024-11-24 00:51:56,213:      Run finished 50 round(s) in 438.49s
# INFO 2024-11-24 00:51:56,214:      	History (loss, distributed):
# INFO 2024-11-24 00:51:56,214:      		round 1: 71.57585311474477
# INFO 2024-11-24 00:51:56,215:      		round 2: 63.08884514188281
# INFO 2024-11-24 00:51:56,215:      		round 3: 61.807243465853055
# INFO 2024-11-24 00:51:56,215:      		round 4: 61.67688851787309
# INFO 2024-11-24 00:51:56,216:      		round 5: 61.71009397678272
# INFO 2024-11-24 00:51:56,216:      		round 6: 59.56731239457429
# INFO 2024-11-24 00:51:56,217:      		round 7: 57.637364878085954
# INFO 2024-11-24 00:51:56,217:      		round 8: 58.16593184280271
# INFO 2024-11-24 00:51:56,217:      		round 9: 56.03670587867064
# INFO 2024-11-24 00:51:56,218:      		round 10: 56.2977210086702
# INFO 2024-11-24 00:51:56,218:      		round 11: 54.80814670819462
# INFO 2024-11-24 00:51:56,219:      		round 12: 55.94052165118833
# INFO 2024-11-24 00:51:56,219:      		round 13: 56.452486215068085
# INFO 2024-11-24 00:51:56,219:      		round 14: 53.66689328210439
# INFO 2024-11-24 00:51:56,220:      		round 15: 54.71724400371641
# INFO 2024-11-24 00:51:56,220:      		round 16: 52.43179172314383
# INFO 2024-11-24 00:51:56,220:      		round 17: 51.89200748943124
# INFO 2024-11-24 00:51:56,220:      		round 18: 50.68955636741685
# INFO 2024-11-24 00:51:56,221:      		round 19: 49.50529530249475
# INFO 2024-11-24 00:51:56,221:      		round 20: 51.949265941110774
# INFO 2024-11-24 00:51:56,222:      		round 21: 53.07527308070419
# INFO 2024-11-24 00:51:56,222:      		round 22: 51.257041926839555
# INFO 2024-11-24 00:51:56,222:      		round 23: 49.514514567159594
# INFO 2024-11-24 00:51:56,223:      		round 24: 47.197468684907676
# INFO 2024-11-24 00:51:56,223:      		round 25: 48.12418079585903
# INFO 2024-11-24 00:51:56,223:      		round 26: 49.124421030122136
# INFO 2024-11-24 00:51:56,224:      		round 27: 49.579617919980016
# INFO 2024-11-24 00:51:56,224:      		round 28: 49.9339864851593
# INFO 2024-11-24 00:51:56,224:      		round 29: 48.3549284648352
# INFO 2024-11-24 00:51:56,225:      		round 30: 49.322645707456154
# INFO 2024-11-24 00:51:56,225:      		round 31: 49.657823041012925
# INFO 2024-11-24 00:51:56,225:      		round 32: 48.58547377941395
# INFO 2024-11-24 00:51:56,226:      		round 33: 49.17652303212742
# INFO 2024-11-24 00:51:56,226:      		round 34: 49.67575089849998
# INFO 2024-11-24 00:51:56,226:      		round 35: 47.073153585022794
# INFO 2024-11-24 00:51:56,226:      		round 36: 49.87632660043256
# INFO 2024-11-24 00:51:56,227:      		round 37: 45.550663043457625
# INFO 2024-11-24 00:51:56,227:      		round 38: 46.55493548527351
# INFO 2024-11-24 00:51:56,228:      		round 39: 48.76952664784949
# INFO 2024-11-24 00:51:56,228:      		round 40: 49.911140218296694
# INFO 2024-11-24 00:51:56,228:      		round 41: 48.026152990590134
# INFO 2024-11-24 00:51:56,229:      		round 42: 50.0519708387022
# INFO 2024-11-24 00:51:56,229:      		round 43: 50.78254666977493
# INFO 2024-11-24 00:51:56,229:      		round 44: 49.21434965234696
# INFO 2024-11-24 00:51:56,230:      		round 45: 45.42457477246526
# INFO 2024-11-24 00:51:56,230:      		round 46: 46.5789915472418
# INFO 2024-11-24 00:51:56,230:      		round 47: 47.38484148322261
# INFO 2024-11-24 00:51:56,231:      		round 48: 48.115301608253
# INFO 2024-11-24 00:51:56,231:      		round 49: 46.8506846888266
# INFO 2024-11-24 00:51:56,231:      		round 50: 48.71804060811832
# INFO 2024-11-24 00:51:56,232:
# DEBUG 2024-11-24 00:51:56,237:     ServerApp finished running.
# DEBUG 2024-11-24 00:51:56,238:     ServerApp finished running.
# DEBUG 2024-11-24 00:51:56,238:     Triggered stop event for Simulation Engine.
# DEBUG 2024-11-24 00:51:57,201:     Terminated 16 actors
# (ClientAppActor pid=1105976) /home/fredrik/BTH/DV2607/part2/flower_env/lib/python3.12/site-packages/datasets/utils/_dill.py:385: DeprecationWarning: co_lnotab is deprecated, use co_lines instead. [repeated 4x across cluster]
# (ClientAppActor pid=1105976)   obj.co_lnotab,  # for < python 3.10 [not counted in args] [repeated 4x across cluster]
# DEBUG 2024-11-24 00:51:58,637:     Terminated RayBackend
# DEBUG 2024-11-24 00:51:58,638:     Stopping Simulation Engine now.
# Best Parameters:
# Scenario            Two_Attackers_NonIID
# NOISE_MULTIPLIER                     0.5
# CLIPPING_NORM                        5.0
# Final_Accuracy                   0.48411
# Name: 3, dtype: object
